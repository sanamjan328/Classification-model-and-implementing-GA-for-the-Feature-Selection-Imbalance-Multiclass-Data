# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
from pathlib import Path
data_dir = Path('/Users/sanamjankurban/Documents/Jupyter_projects/Data Analysis Examples/DataBases')

import os
os.listdir(data_dir)
# Out:
# ['-disbtribution-worldwide-2020-03-22.csv',
#  'hypothyroid.csv',
#  'dataset.xlsx',
#  'Mall_Customers.csv',
#  '-Investment-Tracker-2019-Fall-FINAL.csv',
#  '.DS_Store',
#  'nesarc_pds.csv',
#  '-disbtribution-worldwide-2020-03-31.csv',
#  'AssigmentsData',
#  'TÜRKİYE son veriler.xlsx',
#  'Rapor 7260 ABCF MO MT Mean Duration Session.xlsx',
#  'Sample - Superstore.xls',
#  'addhealth_pds.csv',
#  'Classified Data',
#  'College_Data',
#  'winequality-red.csv',
#  'FuelConsumptionCo2.csv',
#  'adult_income_data.csv',
#  'COVID-19-geographic-disbtribution-worldwide-2020-03-31.xlsx',
#  'tree_addhealth.csv',
#  'China-Global-Investment-Tracker-2019-Fall-FINAL.xlsx',
#  'USA_Housing.csv',
#  'Readme.md',
#  'titanic_test.csv',
#  'marscrater_pds.csv',
#  'covid19-global-forecasting-week-1.zip',
#  'slump_test.csv',
#  'covid19-global-forecasting-week-1',
#  'ool_pds.csv',
#  'china_gdp.csv',
#  'KNN_Project_Data',
#  'Height_Weight.xlsx',
#  'dataset.csv',
#  'gapminder.csv',
# ...

# %%
df = pd.read_excel(data_dir/"Rapor 7260 ABCF MO MT Mean Duration Session.xlsx", "Q1")
df.head(10)
# Out:
#                 DATETIME            NE  ABCF_MO_SES_DUR  ABCF_MO_SES_DUR_PRE  \
# 0  2/23/2021  2:00:00 PM  SE2900AHLH02            92.50                97.25
# 1  2/23/2021  2:00:00 PM  SE2900UMRH02            91.50                95.75
# 2  2/23/2021  2:00:00 PM  SE2980AHLH06            94.50                98.25
# 3  2/23/2021  2:00:00 PM  SE2980AHLH07            94.25                98.00
# 4  2/23/2021  2:00:00 PM  SE2980IZMH04            89.25                93.00
# 5  2/23/2021  2:00:00 PM  SE2980IZMH05            90.00                93.25
# 6  2/23/2021  2:00:00 PM  SE2980UMRH05            94.75                98.25
# 7  2/23/2021  2:00:00 PM  SE2980UMRH06            95.00                98.50
# 8  2/23/2021  1:00:00 PM  SE2900AHLH02            97.25               100.00
# 9  2/23/2021  1:00:00 PM  SE2900UMRH02            95.75                96.00
#
#    ABCF_MT_SES_DUR  ABCF_MT_SES_DUR_PRE
# 0            91.25                93.50
# 1            90.50                92.00
# ...

# %%
df["MO_VALUE"] = df.ABCF_MO_SES_DUR_PRE - df.ABCF_MO_SES_DUR
df["MT_VALUE"] = df.ABCF_MT_SES_DUR_PRE - df.ABCF_MT_SES_DUR
df
# Out:
#                   DATETIME            NE  ABCF_MO_SES_DUR  \
# 0    2/23/2021  2:00:00 PM  SE2900AHLH02            92.50
# 1    2/23/2021  2:00:00 PM  SE2900UMRH02            91.50
# 2    2/23/2021  2:00:00 PM  SE2980AHLH06            94.50
# 3    2/23/2021  2:00:00 PM  SE2980AHLH07            94.25
# 4    2/23/2021  2:00:00 PM  SE2980IZMH04            89.25
# 5    2/23/2021  2:00:00 PM  SE2980IZMH05            90.00
# 6    2/23/2021  2:00:00 PM  SE2980UMRH05            94.75
# 7    2/23/2021  2:00:00 PM  SE2980UMRH06            95.00
# 8    2/23/2021  1:00:00 PM  SE2900AHLH02            97.25
# 9    2/23/2021  1:00:00 PM  SE2900UMRH02            95.75
# 10   2/23/2021  1:00:00 PM  SE2980AHLH06            98.25
# 11   2/23/2021  1:00:00 PM  SE2980AHLH07            98.00
# 12   2/23/2021  1:00:00 PM  SE2980IZMH04            93.00
# 13   2/23/2021  1:00:00 PM  SE2980IZMH05            93.25
# 14   2/23/2021  1:00:00 PM  SE2980UMRH05            98.25
# ...
