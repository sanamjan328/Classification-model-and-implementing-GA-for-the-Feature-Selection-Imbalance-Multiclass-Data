# %%
import pandas as pd

# %%
import numpy as np

# %%
array_1 = np.array([['sanam', 44], ['gul', 44], ['mehmet', 21], ['toshqan', 5], ['ali', 32]])
df1 = pd.DataFrame(array_1, columns = ['name', 'no'])

# %%
array_1 = np.array([['sanam', 44], ['gul', 44], ['mehmet', 21], ['toshqan', 5], ['ali', 32]])
df1 = pd.DataFrame(array_1, columns = ['name', 'no'])
